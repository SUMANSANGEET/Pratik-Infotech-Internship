# %% [markdown]
# ## 🔹 Step 1: Data Preparation (Python → CSV)
#
# **Export your cleaned dataset:**

# %%
import pandas as pd

# Create or load your DataFrame
social_df = pd.DataFrame({
    "platform": ["Twitter", "Instagram", "Facebook"],
    "engagement": [120, 340, 220]
})

# %%
social_df.to_csv("social_media_engagement.csv", index=False)

# %%
social_df.to_csv
# Out:
# <bound method NDFrame.to_csv of     platform  engagement
# 0    Twitter         120
# 1  Instagram         340
# 2   Facebook         220>

# %% [markdown]
# ## 🔹 Step 2: Load into Power BI
#
# Open Power BI Desktop
#
# Click Get Data → Text/CSV
#
# Load social_media_engagement.csv
